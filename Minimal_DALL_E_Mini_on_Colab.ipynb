# %% [markdown]
# <a href="https://colab.research.google.com/github/darshankakkad/chatGPTcollab/blob/main/Minimal_DALL_E_Mini_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install min-dalle -q

# %%
from min_dalle import MinDalle

model = MinDalle(is_mega=True, is_reusable=True)

# %%
# %%time

text = "robots enjoying sunset in paris" 
seed = 6  
grid_size = 2  

display(model.generate_image(text, seed, grid_size))
# Out:
# tokenizing text
# ['Ġrobots']
# ['Ġenjoying']
# ['Ġsunset']
# ['Ġin']
# ['Ġparis']
# text tokens [0, 13972, 19059, 4450, 91, 2358, 2]
# encoding text tokens
# sampling image tokens
# detokenizing image
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8A20545910>
# CPU times: user 31.9 s, sys: 8.69 ms, total: 31.9 s
# Wall time: 32 s
